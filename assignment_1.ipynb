# %% [markdown]
# # dataset origin https://raw.githubusercontent.com/alexeygrigorev/datasets/master/laptops.csv

# %%
# !python -m wget https://raw.githubusercontent.com/alexeygrigorev/datasets/master/laptops.csv
# Out:
# Saved under laptops.csv

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Q1. Pandas version
# What's the version of Pandas that you installed?
#
# You can get the version information using the __version__ field:

# %%
pd.__version__
# Out:
# '2.2.3'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df = pd.read_csv('laptops.csv')
df.shape[0]
# Out:
# 2160

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df['Brand'].nunique()
# Out:
# 27

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.isna().sum()
# Out:
# Laptop             0
# Status             0
# Brand              0
# Model              0
# CPU                0
# RAM                0
# Storage            0
# Storage type      42
# GPU             1371
# Screen             4
# Touch              0
# Final Price        0
# dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df[df['Brand']=='Dell']['Final Price'].max()
# Out:
# np.float64(3936.0)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df['Screen'].median()
# Out:
# np.float64(15.6)

# %%
df['Screen'].value_counts()
# Out:
# Screen
# 15.60    1009
# 14.00     392
# 16.00     174
# 17.30     161
# 13.30     131
# 16.10      48
# 17.00      33
# 13.00      27
# 15.00      21
# 13.40      19
# 13.50      19
# 11.60      16
# 14.20      14
# 12.30      13
# 14.10      11
# 13.60      11
# 16.20      10
# 15.30       8
# 10.50       7
# 12.40       6
# 14.40       6
# 15.40       5
# 12.00       4
# 18.00       3
# 14.50       3
# 13.90       2
# 12.50       1
# 10.95       1
# 10.10       1
# Name: count, dtype: int64

# %%
df['Screen'].fillna(15.60).median()
# Out:
# np.float64(15.6)

# %% [markdown]
# # Unchanged.
# # No

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
X = df[df['Brand'] == 'Innjoo'][['RAM','Storage','Screen']].to_numpy()

# %%
XTX = X.T@X

# %%
import numpy as np
from numpy.linalg import inv
XTX_inverse = inv(XTX)

# %%
y = [1100,1300,800,900,1000,1100]
np.sum(XTX_inverse@X.T@y)
# Out:
# np.float64(91.2998806299555)

# %% [markdown]
# 91.30
